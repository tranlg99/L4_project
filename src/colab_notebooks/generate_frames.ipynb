# %%
# connecting drive to colab notebook so I dont need to upload files on every instance
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# dependencies
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %%
# create folder to store the frames in
# !mkdir frames

# %%
# generate .jpg frames
# bash script taken from https://github.com/gsssrao/youtube-8m-videos-frames
# !bash /content/drive/MyDrive/youtube-8m-videos-frames/generateframesfromvideos.sh /content/drive/MyDrive/youtube-8m-videos-frames/videos frames jpg

# %%
# zip the folder
# !zip -r /content/frames.zip /content/frames

# %%
# copy zip file to drive
# !cp frames.zip "/content/drive/MyDrive/youtube-8m-videos-frames/"

# %%
# alternatively download the zip file
from google.colab import files
files.download('/content/frames.zip')

# %%
# !du -h frames.zip
# Out:
# 5.8G	frames.zip
